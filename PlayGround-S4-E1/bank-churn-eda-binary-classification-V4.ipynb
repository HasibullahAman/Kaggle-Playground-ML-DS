# %% [markdown]
# <center><span style="font-family:Comic Sans MS; color:navy "><h1>Binary Classification with a Bank Churn Dataset</h1></span></center>
# <br><br>
# <div style="display: flex; flex-direction: row; align-items: center;">
#     <div style="flex: 0; margin-top: 8px;">
#         <img src="https://img.freepik.com/premium-vector/bank-building-money-bank-financing-money-exchange-financial-services_625536-425.jpg?w=360" alt="Image" style="max-width: 300px; max-height: 350px;" />
#     </div>
#     <div style="flex: 1; margin-left: 30px; margin-top: 6px">
#         <p style="font-weight: bold; color: black; font-size: 17px">Introduction</p>
#         <p>
# The bank customer churn dataset is a commonly used dataset for predicting customer churn in the banking industry. It contains information on bank customers who either left the bank or continue to be a customer
#         </p>
#     </div>
# </div>

# %% [markdown]
# # <b>a <span style='color:#94D4F6'>|</span> Table of Conents</b>
# <a id="toc"></a>
# - [1. Import Libraries](#1)
# - [2. Read Dataset](#2)
# - [3. Visualization](#3)
# - [4. Preprocessing](#4)
# - [6. Split Dataset](#6)
# - [7. Modeling](#7)
# - [9. Evaluation](#8)
# - [8. Predict test data](#9)

# %% [markdown]
# # <b>b <span style='color:#94D4F6'>|</span> About DataSet</b>

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# The bank customer churn dataset is a commonly used dataset for predicting customer churn in the banking industry. It contains information on bank customers who either left the bank or continue to be a customer. The dataset includes the following attributes:
#
#
# **Customer ID:** A unique identifier for each customer
#
# **Surname:** The customer's surname or last name
#
# **Credit Score:** A numerical value representing the customer's credit score
#
# **Geography:** The country where the customer resides (France, Spain or Germany)
#
# **Gender:** The customer's gender (Male or Female)
#
# **Age:** The customer's age.
#
# **Tenure:** The number of years the customer has been with the bank
#
# **Balance:** The customer's account balance
#
# **NumOfProducts:** The number of bank products the customer uses (e.g., savings account, credit card)
#
# **HasCrCard:** Whether the customer has a credit card (1 = yes, 0 = no)
#
# **IsActiveMember:** Whether the customer is an active member (1 = yes, 0 = no)
#
# **EstimatedSalary:** The estimated salary of the customer
#
# **Exited:** Whether the customer has churned (1 = yes, 0 = no)

# %% [markdown]
# <a id="1"></a>
# # <b>1 <span style='color:#94D4F6'>|</span> Import Libraries</b>

# %%
import numpy as np # for calculation
import pandas as pd # for work with Dataset

# for Visualization 
import matplotlib.pyplot as plt
import seaborn as sns

# PreProcessing
from sklearn.model_selection import(
    train_test_split,# used to split the data into training and testing
    cross_val_score,
)
from sklearn.preprocessing import MinMaxScaler

# Modeling
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier


# For Evaluation 
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# Hyperparameters Tuning
import optuna
from sklearn.metrics import log_loss
import torch

# %% [markdown]
# <a id="2"></a>
# # <b>2 <span style='color:#94D4F6'>|</span> Read Dataset</b>

# %%
# main dataset as df
# test datset as test
# sample_submission dataset as ss
# original dataset as od
df = pd.read_csv('./Data/train.csv')
test = pd.read_csv('./Data/test.csv')
ss = pd.read_csv('./Data/sample_submission.csv')
od = pd.read_csv('./Data/Churn_Modelling.csv')

# %% [markdown]
# #### I have use the combined data set from this competition and the orignal one . link to combined dataset [Combined](https://www.kaggle.com/datasets/devavratpatil/combined/data)

# %%
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
od.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1        1.0             1.0
# 1       1   83807.86              1        0.0             1.0
# 2       8  159660.80              3        1.0             0.0
# 3       1       0.00              2        0.0             0.0
# 4       2  125510.82              1        NaN             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# Here, we have 14 columns with different data types, including both categorical and numerical variables. and as you can see, our dataset does not contain any null values. However, We need to perform preprocessing operations on these variables to transform them into suitable inputs for our modeling step.

# %% [markdown]
# ### Shape

# %%
print('shape of training dataset:')
print('there are {} rows and {} columns in training dataset.'.format(df.shape[0],df.shape[1]))
print('shape of test dataset:')
print('there are {} rows and {} columns in test dataset.'.format(test.shape[0],test.shape[1]))
print('shape of original dataset:')
print('there are {} rows and {} columns original dataset.'.format(od.shape[0],od.shape[1]))
# Out:
# shape of training dataset:
# there are 165034 rows and 14 columns in training dataset.
# shape of test dataset:
# there are 110023 rows and 13 columns in test dataset.
# shape of original dataset:
# there are 10002 rows and 14 columns original dataset.

# %% [markdown]
# ### Describe the dataset

# %%
df.describe().style.background_gradient(cmap = 'inferno')
# Out:
# <style type="text/css">
# #T_14d32_row0_col0, #T_14d32_row0_col2, #T_14d32_row0_col3, #T_14d32_row0_col4, #T_14d32_row0_col6, #T_14d32_row0_col7, #T_14d32_row0_col8, #T_14d32_row0_col10, #T_14d32_row6_col1, #T_14d32_row7_col0, #T_14d32_row7_col1, #T_14d32_row7_col5, #T_14d32_row7_col9 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_14d32_row0_col1, #T_14d32_row7_col2 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_14d32_row0_col5 {
#   background-color: #eb6628;
#   color: #f1f1f1;
# }
# #T_14d32_row0_col9 {
#   background-color: #fcb216;
#   color: #000000;
# }
# #T_14d32_row1_col0, #T_14d32_row5_col0 {
#   background-color: #ba3655;
#   color: #f1f1f1;
# }
# #T_14d32_row1_col1, #T_14d32_row4_col1, #T_14d32_row5_col1 {
#   background-color: #f9fc9d;
#   color: #000000;
# }
# #T_14d32_row1_col2, #T_14d32_row1_col3, #T_14d32_row1_col4, #T_14d32_row1_col6, #T_14d32_row1_col7, #T_14d32_row1_col8, #T_14d32_row1_col10, #T_14d32_row2_col1, #T_14d32_row2_col2, #T_14d32_row2_col3, #T_14d32_row2_col4, #T_14d32_row2_col6, #T_14d32_row2_col7, #T_14d32_row2_col8, #T_14d32_row2_col10, #T_14d32_row3_col0, #T_14d32_row3_col2, #T_14d32_row3_col3, #T_14d32_row3_col4, #T_14d32_row3_col5, #T_14d32_row3_col6, #T_14d32_row3_col7, #T_14d32_row3_col8, #T_14d32_row3_col9, #T_14d32_row3_col10, #T_14d32_row4_col2, #T_14d32_row4_col3, #T_14d32_row4_col4, #T_14d32_row4_col5, #T_14d32_row4_col6, #T_14d32_row4_col7, #T_14d32_row4_col8, #T_14d32_row4_col10, #T_14d32_row5_col2, #T_14d32_row5_col3, #T_14d32_row5_col4, #T_14d32_row5_col5, #T_14d32_row5_col6, #T_14d32_row5_col7, #T_14d32_row5_col8, #T_14d32_row5_col10, #T_14d32_row6_col2, #T_14d32_row6_col3, #T_14d32_row6_col4, #T_14d32_row6_col6, #T_14d32_row6_col7, #T_14d32_row6_col8, #T_14d32_row6_col10, #T_14d32_row7_col3, #T_14d32_row7_col4, #T_14d32_row7_col6, #T_14d32_row7_col7, #T_14d32_row7_col8, #T_14d32_row7_col10 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_14d32_row1_col5 {
#   background-color: #4a0c6b;
#   color: #f1f1f1;
# }
# #T_14d32_row1_col9 {
#   background-color: #d24644;
#   color: #f1f1f1;
# }
# #T_14d32_row2_col0 {
#   background-color: #65156e;
#   color: #f1f1f1;
# }
# #T_14d32_row2_col5, #T_14d32_row2_col9 {
#   background-color: #57106e;
#   color: #f1f1f1;
# }
# #T_14d32_row3_col1 {
#   background-color: #f6fa96;
#   color: #000000;
# }
# #T_14d32_row4_col0 {
#   background-color: #550f6d;
#   color: #f1f1f1;
# }
# #T_14d32_row4_col9 {
#   background-color: #88226a;
#   color: #f1f1f1;
# }
# #T_14d32_row5_col9 {
#   background-color: #d94d3d;
#   color: #f1f1f1;
# }
# #T_14d32_row6_col0 {
#   background-color: #f98c0a;
#   color: #f1f1f1;
# }
# #T_14d32_row6_col5 {
#   background-color: #b3325a;
#   color: #f1f1f1;
# }
# #T_14d32_row6_col9 {
#   background-color: #fb9906;
#   color: #000000;
# }
# </style>
# <table id="T_14d32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14d32_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_14d32_level0_col1" class="col_heading level0 col1" >CustomerId</th>
#       <th id="T_14d32_level0_col2" class="col_heading level0 col2" >CreditScore</th>
#       <th id="T_14d32_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_14d32_level0_col4" class="col_heading level0 col4" >Tenure</th>
#       <th id="T_14d32_level0_col5" class="col_heading level0 col5" >Balance</th>
#       <th id="T_14d32_level0_col6" class="col_heading level0 col6" >NumOfProducts</th>
#       <th id="T_14d32_level0_col7" class="col_heading level0 col7" >HasCrCard</th>
#       <th id="T_14d32_level0_col8" class="col_heading level0 col8" >IsActiveMember</th>
#       <th id="T_14d32_level0_col9" class="col_heading level0 col9" >EstimatedSalary</th>
#       <th id="T_14d32_level0_col10" class="col_heading level0 col10" >Exited</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14d32_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_14d32_row0_col0" class="data row0 col0" >165034.000000</td>
#       <td id="T_14d32_row0_col1" class="data row0 col1" >165034.000000</td>
#       <td id="T_14d32_row0_col2" class="data row0 col2" >165034.000000</td>
#       <td id="T_14d32_row0_col3" class="data row0 col3" >165034.000000</td>
#       <td id="T_14d32_row0_col4" class="data row0 col4" >165034.000000</td>
#       <td id="T_14d32_row0_col5" class="data row0 col5" >165034.000000</td>
#       <td id="T_14d32_row0_col6" class="data row0 col6" >165034.000000</td>
#       <td id="T_14d32_row0_col7" class="data row0 col7" >165034.000000</td>
#       <td id="T_14d32_row0_col8" class="data row0 col8" >165034.000000</td>
#       <td id="T_14d32_row0_col9" class="data row0 col9" >165034.000000</td>
#       <td id="T_14d32_row0_col10" class="data row0 col10" >165034.000000</td>
#     </tr>
#     <tr>
#       <th id="T_14d32_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_14d32_row1_col0" class="data row1 col0" >82516.500000</td>
#       <td id="T_14d32_row1_col1" class="data row1 col1" >15692005.019026</td>
#       <td id="T_14d32_row1_col2" class="data row1 col2" >656.454373</td>
#       <td id="T_14d32_row1_col3" class="data row1 col3" >38.125888</td>
#       <td id="T_14d32_row1_col4" class="data row1 col4" >5.020353</td>
#       <td id="T_14d32_row1_col5" class="data row1 col5" >55478.086689</td>
#       <td id="T_14d32_row1_col6" class="data row1 col6" >1.554455</td>
#       <td id="T_14d32_row1_col7" class="data row1 col7" >0.753954</td>
#       <td id="T_14d32_row1_col8" class="data row1 col8" >0.497770</td>
#       <td id="T_14d32_row1_col9" class="data row1 col9" >112574.822734</td>
#       <td id="T_14d32_row1_col10" class="data row1 col10" >0.211599</td>
#     </tr>
#     <tr>
#       <th id="T_14d32_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_14d32_row2_col0" class="data row2 col0" >47641.356500</td>
#       <td id="T_14d32_row2_col1" class="data row2 col1" >71397.816791</td>
#       <td id="T_14d32_row2_col2" class="data row2 col2" >80.103340</td>
#       <td id="T_14d32_row2_col3" class="data row2 col3" >8.867205</td>
#       <td id="T_14d32_row2_col4" class="data row2 col4" >2.806159</td>
#       <td id="T_14d32_row2_col5" class="data row2 col5" >62817.663278</td>
#       <td id="T_14d32_row2_col6" class="data row2 col6" >0.547154</td>
#       <td id="T_14d32_row2_col7" class="data row2 col7" >0.430707</td>
#       <td id="T_14d32_row2_col8" class="data row2 col8" >0.499997</td>
#       <td id="T_14d32_row2_col9" class="data row2 col9" >50292.865585</td>
#       <td id="T_14d32_row2_col10" class="data row2 col10" >0.408443</td>
#     </tr>
#     <tr>
#       <th id="T_14d32_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_14d32_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_14d32_row3_col1" class="data row3 col1" >15565701.000000</td>
#       <td id="T_14d32_row3_col2" class="data row3 col2" >350.000000</td>
#       <td id="T_14d32_row3_col3" class="data row3 col3" >18.000000</td>
#       <td id="T_14d32_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_14d32_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_14d32_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_14d32_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_14d32_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_14d32_row3_col9" class="data row3 col9" >11.580000</td>
#       <td id="T_14d32_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_14d32_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_14d32_row4_col0" class="data row4 col0" >41258.250000</td>
#       <td id="T_14d32_row4_col1" class="data row4 col1" >15633141.000000</td>
#       <td id="T_14d32_row4_col2" class="data row4 col2" >597.000000</td>
#       <td id="T_14d32_row4_col3" class="data row4 col3" >32.000000</td>
#       <td id="T_14d32_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_14d32_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_14d32_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_14d32_row4_col7" class="data row4

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# And here is some statistical information about our dataset. I will create clear plots to present the data more effectively.

# %% [markdown]
# ### Columns

# %%
df.columns
# Out:
# Index(['id', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# ### Drop ID&Surname columnsZ

# %%
testID = test['id']
df.drop(['id', 'Surname'],axis=1,inplace=True)
od.drop(['RowNumber','Surname'],axis = 1, inplace = True)
test.drop(['id', 'Surname'],axis = 1,inplace =True)

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# Here, I should identify if there is any similarity between the dataset ID and customer ID. In the previous statement, I mentioned that I dropped the dataset or row number, but I meant to say that I did not drop the customer ID. The customer ID is a unique identifier for each customer, and it is a valuable column for our analysis.

# %% [markdown]
# ### Determine the Categorical and Numerical Features

# %%
target = 'Exited'
obj_col = [x for x in df.select_dtypes(include=['object']).columns if x!=target]
num_col = [x for x in df.select_dtypes(exclude =['object']).columns if x!= target]
print(f'obj_columns: {obj_col}')
print(f'num_columns: {num_col}')
# Out:
# obj_columns: ['Geography', 'Gender']
# num_columns: ['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']

# %% [markdown]
# <a id="3"></a>
# # <b>3 <span style='color:#94D4F6'>|</span> Explanatory Data Analysis (EDA)</b>

# %% [markdown]
# <font size="3">Let's see what's the quality of raw dataset.</font>

# %%
def summary(df):
    sum = pd.DataFrame(df.dtypes,columns = ['dtypes'])
    sum['missing#'] = df.isna().sum()
    sum['missing%'] = (df.isna().sum())/len(df)
    sum['unique'] =  df.nunique().values
    sum['count'] = df.count().values
    return sum
summary(df).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_41d27_row0_col1, #T_41d27_row0_col2, #T_41d27_row0_col4, #T_41d27_row1_col1, #T_41d27_row1_col2, #T_41d27_row1_col4, #T_41d27_row2_col1, #T_41d27_row2_col2, #T_41d27_row2_col3, #T_41d27_row2_col4, #T_41d27_row3_col1, #T_41d27_row3_col2, #T_41d27_row3_col3, #T_41d27_row3_col4, #T_41d27_row4_col1, #T_41d27_row4_col2, #T_41d27_row4_col3, #T_41d27_row4_col4, #T_41d27_row5_col1, #T_41d27_row5_col2, #T_41d27_row5_col3, #T_41d27_row5_col4, #T_41d27_row6_col1, #T_41d27_row6_col2, #T_41d27_row6_col4, #T_41d27_row7_col1, #T_41d27_row7_col2, #T_41d27_row7_col3, #T_41d27_row7_col4, #T_41d27_row8_col1, #T_41d27_row8_col2, #T_41d27_row8_col3, #T_41d27_row8_col4, #T_41d27_row9_col1, #T_41d27_row9_col2, #T_41d27_row9_col3, #T_41d27_row9_col4, #T_41d27_row10_col1, #T_41d27_row10_col2, #T_41d27_row10_col4, #T_41d27_row11_col1, #T_41d27_row11_col2, #T_41d27_row11_col3, #T_41d27_row11_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_41d27_row0_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_41d27_row1_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_41d27_row6_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_41d27_row10_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41d27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41d27_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_41d27_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_41d27_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_41d27_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_41d27_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41d27_level0_row0" class="row_heading level0 row0" >CustomerId</th>
#       <td id="T_41d27_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_41d27_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_41d27_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_41d27_row0_col3" class="data row0 col3" >23221</td>
#       <td id="T_41d27_row0_col4" class="data row0 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row1" class="row_heading level0 row1" >CreditScore</th>
#       <td id="T_41d27_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_41d27_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_41d27_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_41d27_row1_col3" class="data row1 col3" >457</td>
#       <td id="T_41d27_row1_col4" class="data row1 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row2" class="row_heading level0 row2" >Geography</th>
#       <td id="T_41d27_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_41d27_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_41d27_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_41d27_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_41d27_row2_col4" class="data row2 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row3" class="row_heading level0 row3" >Gender</th>
#       <td id="T_41d27_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_41d27_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_41d27_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_41d27_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_41d27_row3_col4" class="data row3 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_41d27_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_41d27_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_41d27_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_41d27_row4_col3" class="data row4 col3" >71</td>
#       <td id="T_41d27_row4_col4" class="data row4 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row5" class="row_heading level0 row5" >Tenure</th>
#       <td id="T_41d27_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_41d27_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_41d27_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_41d27_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_41d27_row5_col4" class="data row5 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row6" class="row_heading level0 row6" >Balance</th>
#       <td id="T_41d27_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_41d27_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_41d27_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_41d27_row6_col3" class="data row6 col3" >30075</td>
#       <td id="T_41d27_row6_col4" class="data row6 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row7" class="row_heading level0 row7" >NumOfProducts</th>
#       <td id="T_41d27_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_41d27_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_41d27_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_41d27_row7_col3" class="data row7 col3" >4</td>
#       <td id="T_41d27_row7_col4" class="data row7 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row8" class="row_heading level0 row8" >HasCrCard</th>
#       <td id="T_41d27_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_41d27_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_41d27_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_41d27_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_41d27_row8_col4" class="data row8 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row9" class="row_heading level0 row9" >IsActiveMember</th>
#       <td id="T_41d27_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_41d27_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_41d27_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_41d27_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_41d27_row9_col4" class="data row9 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row10" class="row_heading level0 row10" >EstimatedSalary</th>
#       <td id="T_41d27_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_41d27_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_41d27_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_41d27_row10_col3" class="data row10 col3" >55298</td>
#       <td id="T_41d27_row10_col4" class="data row10 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_41d27_level0_row11" class="row_heading level0 row11" >Exited</th>
#       <td id="T_41d27_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_41d27_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_41d27_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_41d27_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_41d27_row11_col4" class="data row11 col4" >165034</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('----------test data ------------')
summary(test).style.background_gradient(cmap='Blues')
# Out:
# ----------test data ------------
# <style type="text/css">
# #T_1ea82_row0_col1, #T_1ea82_row0_col2, #T_1ea82_row0_col4, #T_1ea82_row1_col1, #T_1ea82_row1_col2, #T_1ea82_row1_col4, #T_1ea82_row2_col1, #T_1ea82_row2_col2, #T_1ea82_row2_col3, #T_1ea82_row2_col4, #T_1ea82_row3_col1, #T_1ea82_row3_col2, #T_1ea82_row3_col3, #T_1ea82_row3_col4, #T_1ea82_row4_col1, #T_1ea82_row4_col2, #T_1ea82_row4_col3, #T_1ea82_row4_col4, #T_1ea82_row5_col1, #T_1ea82_row5_col2, #T_1ea82_row5_col3, #T_1ea82_row5_col4, #T_1ea82_row6_col1, #T_1ea82_row6_col2, #T_1ea82_row6_col4, #T_1ea82_row7_col1, #T_1ea82_row7_col2, #T_1ea82_row7_col3, #T_1ea82_row7_col4, #T_1ea82_row8_col1, #T_1ea82_row8_col2, #T_1ea82_row8_col3, #T_1ea82_row8_col4, #T_1ea82_row9_col1, #T_1ea82_row9_col2, #T_1ea82_row9_col3, #T_1ea82_row9_col4, #T_1ea82_row10_col1, #T_1ea82_row10_col2, #T_1ea82_row10_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1ea82_row0_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_1ea82_row1_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_1ea82_row6_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_1ea82_row10_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1ea82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ea82_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_1ea82_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_1ea82_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_1ea82_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_1ea82_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ea82_level0_row0" class="row_heading level0 row0" >CustomerId</th>
#       <td id="T_1ea82_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_1ea82_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1ea82_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_1ea82_row0_col3" class="data row0 col3" >19698</td>
#       <td id="T_1ea82_row0_col4" class="data row0 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row1" class="row_heading level0 row1" >CreditScore</th>
#       <td id="T_1ea82_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_1ea82_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_1ea82_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_1ea82_row1_col3" class="data row1 col3" >454</td>
#       <td id="T_1ea82_row1_col4" class="data row1 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row2" class="row_heading level0 row2" >Geography</th>
#       <td id="T_1ea82_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_1ea82_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_1ea82_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_1ea82_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_1ea82_row2_col4" class="data row2 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row3" class="row_heading level0 row3" >Gender</th>
#       <td id="T_1ea82_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_1ea82_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_1ea82_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_1ea82_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_1ea82_row3_col4" class="data row3 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_1ea82_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_1ea82_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_1ea82_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_1ea82_row4_col3" class="data row4 col3" >74</td>
#       <td id="T_1ea82_row4_col4" class="data row4 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row5" class="row_heading level0 row5" >Tenure</th>
#       <td id="T_1ea82_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_1ea82_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_1ea82_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_1ea82_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_1ea82_row5_col4" class="data row5 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row6" class="row_heading level0 row6" >Balance</th>
#       <td id="T_1ea82_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_1ea82_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_1ea82_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_1ea82_row6_col3" class="data row6 col3" >22513</td>
#       <td id="T_1ea82_row6_col4" class="data row6 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row7" class="row_heading level0 row7" >NumOfProducts</th>
#       <td id="T_1ea82_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_1ea82_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_1ea82_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_1ea82_row7_col3" class="data row7 col3" >4</td>
#       <td id="T_1ea82_row7_col4" class="data row7 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row8" class="row_heading level0 row8" >HasCrCard</th>
#       <td id="T_1ea82_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_1ea82_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_1ea82_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_1ea82_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_1ea82_row8_col4" class="data row8 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row9" class="row_heading level0 row9" >IsActiveMember</th>
#       <td id="T_1ea82_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_1ea82_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_1ea82_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_1ea82_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_1ea82_row9_col4" class="data row9 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_1ea82_level0_row10" class="row_heading level0 row10" >EstimatedSalary</th>
#       <td id="T_1ea82_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_1ea82_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_1ea82_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_1ea82_row10_col3" class="data row10 col3" >41670</td>
#       <td id="T_1ea82_row10_col4" class="data row10 col4" >110023</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Checking Correlation

# %%
columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
data = df[columns]
correlation_matrix = data.corr()
plt.figure(figsize=(10, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
#
# -  The values inside each cell represent the correlation coefficient, which ranges from -1 to 1. A correlation coefficient of 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation between the variables.
#
# - The diagonal line from the top-left to the bottom-right of the heatmap represents the correlation of each variable with itself, which is always 1. These values are not informative for analysis.
#
# - The upper and lower triangular portions of the heatmap are mirror images of each other since the correlation matrix is symmetric.

# %% [markdown]
# ### Label Distribution

# %%
counts = df['Exited'].value_counts()
df_counts = pd.DataFrame({'Class': counts.index, 'Count': counts.values})
print("Count of each Status:")
print(counts)
print("----------------------------------------------------------")
print()


sns.set_palette("Set2")
plt.figure(figsize=(6, 6))
plt.pie(df_counts['Count'], labels=df_counts['Class'], autopct='%1.1f%%',explode=(0.05,0.05), shadow=True, startangle=90, colors=sns.color_palette())
plt.title('Count Distribution of Target Variable')
plt.axis('equal')
plt.show()
# Out:
# Count of each Status:
# 0    130113
# 1     34921
# Name: Exited, dtype: int64
# ----------------------------------------------------------

# %%
columns_histogram_plot = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']
plt.figure(figsize=(15,10))
# loop through the number of rows and data frame columns
for i, columns in enumerate(columns_histogram_plot):
    plt.subplot(3,2,i+1)
    df[columns].hist(bins = 20,color = 'blue', edgecolor ='black')
    plt.title(f'distribution of {columns}')
    plt.xlabel(columns)
    plt.ylabel('Number of Cocustomer')
# Prevents overlap of plots
plt.tight_layout()
plt.show()

# %%
columns_pie_plot = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
for ax, column in zip(axes.flatten(), columns_pie_plot):
    category_counts = df[column].value_counts()
    ax.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f'Proportion of Customers by {column}')
# Prevents overlap of plots
plt.tight_layout()
plt.show()

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")
# Create box plots for the specified numerical columns stratified by 'Exited'
plt.figure(figsize=(12, 8))
for i, column in enumerate(['CreditScore', 'Age', 'Balance', 'EstimatedSalary'], 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='Exited', y=column, data=df)
    plt.title(f'{column} distribution by Exited')
    plt.xlabel('Exited')
    plt.ylabel(column)
# Prevents overlap of plots
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="4"></a>
# # <b>4 <span style='color:#94D4F6'>|</span> Preprocessing</b>

# %%
## utils/functions

# Unique Value
def uniqueValue(columns_name,df):
    return df[columns_name].unique()
# Null value
def DropNullValue(data):
    data.dropna(inplace=True)
    return data
def getMinMaxScaler(data):
    sc=MinMaxScaler()
    sc.fit(df[num_col])
    data[num_col]=sc.transform(data[num_col])
    return data

# %%
# Replace missing values with the mode (most frequent value)
df['Geography'].fillna(df['Geography'].mode()[0], inplace=True)
                            
# Concatenate the datasets vertically
df = pd.concat(objs=[df, od]).reset_index(drop=True)

# drop null value
df = DropNullValue(df)
test = DropNullValue(test)
# Normalization 
df = getMinMaxScaler(df)
test = getMinMaxScaler(test)

# %% [markdown]
# ### Encode Categorical Variables to Numerical

# %%
Geograpy_unique = uniqueValue('Geography',df)
Gender_unique = uniqueValue('Gender',df)
print(Geograpy_unique)
print(Gender_unique)
# Out:
# ['France' 'Spain' 'Germany']
# ['Male' 'Female']

# %%
cate_features = ['Geography', 'Gender']
# Geography
df['Geography'] = df['Geography'].map({
    'France' : 0,
    'Spain': 1,
    'Germany' : 2,
}).astype('int')

# Gender
df['Gender'] = df['Gender'].map({
    'Male' : 0,
    'Female' : 1,
}).astype('int')

test['Geography'] = test['Geography'].map({
    'France' : 0,
    'Spain': 1,
    'Germany' : 2,
}).astype('int')

# Gender
test['Gender'] = test['Gender'].map({
    'Male' : 0,
    'Female' : 1,
}).astype('int')

# %% [markdown]
# ### Detect Outliers

# %%
# tmp_df = df.copy()

# # Calculate the mean and standard deviation for each column
# means = tmp_df[num_col].mean()
# std_devs = tmp_df[num_col].std()

# # Define a threshold for what you consider to be an outlier, typically 3 standard deviations from the mean
# n_stds = 6
# thresholds = n_stds * std_devs

# # Detect outliers
# outliers = (np.abs(tmp_df[num_col] - means) > thresholds).any(axis=1)
# print(f"Detected {sum(outliers)} that are more than {n_stds} SDs away from mean...")

# # Remove Outlier
# outliers_df = tmp_df[outliers]
# print(f"Train data shape BEFORE outlier removal: {df.shape}")
# df = tmp_df[~outliers].reset_index(drop=True)
# print()
# print(f"Train data shape AFTER outlier removal: {df.shape}")

# %% [markdown]
# <a id="6"></a>
# ## Spliting The Dataset to Train and Test

# %%
df.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
y_df = df['Exited']
train_df = df.drop('Exited',axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df,y_df, test_size=0.2, shuffle=True, random_state=42)

# %% [markdown]
# <a id="7"></a>
# # <b>4 <span style='color:#94D4F6'>|</span> Modeling</b>

# %%
init_models = {
    'xgb' : XGBClassifier(),
    'lgbmC' : LGBMClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'CatBoost': CatBoostClassifier(verbose=False),
}

# %%
R2 = []
models_names = []
for i,(key,model) in enumerate(init_models.items()):
    model.fit(X_train,y_train)
    models_names.append(key)
    R2.append(np.mean(cross_val_score(model,X_train,y_train,cv=5)))
models_scores = pd.DataFrame({'model name':models_names,'R2 score':R2})
models_scores.head(7)
# Out:
#           model name  R2 score
# 0                xgb  0.863443
# 1              lgbmC  0.864472
# 2  Gradient Boosting  0.863236
# 3           CatBoost  0.864293

# %%
fig, ax = plt.subplots()
ax.set_xticklabels(ax.get_xticklabels(), rotation=70)
ax.set_title("models R2 score")
sns.barplot(data=models_scores, x='model name', y="R2 score")
plt.show()
# Out:
# C:\Users\Hasibullah Aman\AppData\Local\Temp\ipykernel_12780\303085194.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=70)

# %% [markdown]
# ## Hyperparameters Tuning

# %%
# def objective(trial):
#     xgb_params = {
#         'lambda': trial.suggest_float('lambda', 1e-8, 1.0, log=True),
#         'alpha': trial.suggest_float('alpha', 1e-8, 1.0, log=True),
#         'max_depth': trial.suggest_int('max_depth', 2, 15),
#         'eta': trial.suggest_float('eta', 0.001, 0.1, log=True),
#         'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
#         'subsample': trial.suggest_float('subsample', 0.1, 1.0),
#         'min_child_weight': trial.suggest_int('min_child_weight', 1, 15),
#         'n_estimators': trial.suggest_int('n_estimators', 500, 1000),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
#         'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
#         'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
#     }

#     model_xgb = XGBClassifier(**xgb_params, n_jobs=-1)
#     model_xgb.fit(X_train, y_train)

#     y_val_pred_xgb = model_xgb.predict_proba(X_test)
#     score = log_loss(y_test, y_val_pred_xgb)

#     return score

# # Create an Optuna study and optimize the objective function
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=8000)

# %%
# Print the best hyperparameters and the corresponding score
# print("Best Hyperparameters: ", study.best_params)
# print("Best Score: ", study.best_value)

# XGBoostBestParm = study.best_params
# XGBoostBestParmVal = study.best_value

# %%
# def objective(trial):
#     lgbm_params = {
#         'lambda': trial.suggest_float('lambda', 1e-8, 1.0, log=True),
#         'alpha': trial.suggest_float('alpha', 1e-8, 1.0, log=True),
#         'max_depth': trial.suggest_int('max_depth', 2, 15),
#         'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
#         'n_estimators': trial.suggest_int('n_estimators', 500, 1000),
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
#         'subsample': trial.suggest_float('subsample', 0.1, 1.0),
#         'min_child_samples': trial.suggest_int('min_child_samples', 1, 15),
#         'num_leaves': trial.suggest_int('num_leaves', 2, 256),
#     }

#     model_lgbm = LGBMClassifier(**lgbm_params, n_jobs=-1)
#     model_lgbm.fit(X_train, y_train)

#     y_val_pred_lgbm = model_lgbm.predict_proba(X_test)
#     score = log_loss(y_test, y_val_pred_lgbm)

#     return score

# # Create an Optuna study and optimize the objective function
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=8000)

# %%
# Print the best hyperparameters and the corresponding score
# print("Best Hyperparameters: ", study.best_params)
# print("Best Score: ", study.best_value)

# %%
LGB_params = {'n_estimators':1378,
               'max_depth': 45, 
               'learning_rate': 0.02280891846048891,
               'min_child_weight': 2.829627687023079, 
               'min_child_samples': 239,
               'subsample': 0.9770315658429933,
               'subsample_freq': 2,
               'colsample_bytree': 0.6533317052372195,
               'num_leaves': 44}

XGB_params = {'booster': 'gbtree', 
        'lambda': 8.803747805736341e-08, 
        'alpha': 0.00010339545129413926,
        'subsample': 0.6472067107394853,
        'colsample_bytree': 0.9225973102702412,
        'max_depth': 5,
        'min_child_weight': 5,
        'eta': 0.12477845463556776,
        'gamma': 0.0021228439224434607,
        'grow_policy': 'lossguide'}

# %%
init_models = {
    'xgb' : XGBClassifier(**XGB_params),
    'lgbmC' : LGBMClassifier(**LGB_params),
    'Gradient Boosting': GradientBoostingClassifier(),
    'CatBoost': CatBoostClassifier(verbose=False),
}

# %%
R2 = []
models_names = []
for i,(key,model) in enumerate(init_models.items()):
    model.fit(X_train,y_train)
    models_names.append(key)
    R2.append(np.mean(cross_val_score(model,X_train,y_train,cv=5)))
models_scores = pd.DataFrame({'model name':models_names,'R2 score':R2})
models_scores.head(7)
# Out:
#           model name  R2 score
# 0                xgb  0.864743
# 1              lgbmC  0.864893
# 2  Gradient Boosting  0.863236
# 3           CatBoost  0.864293

# %%
lgbmC = LGBMClassifier(**LGB_params)
lgbmC.fit(X_train,y_train)
# Out:
# LGBMClassifier(colsample_bytree=0.6533317052372195,
#                learning_rate=0.02280891846048891, max_depth=45,
#                min_child_samples=239, min_child_weight=2.829627687023079,
#                n_estimators=1378, num_leaves=44, subsample=0.9770315658429933,
#                subsample_freq=2)

# %%
y_pred = lgbmC.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8654269146170765

# %%
lgbmC = LGBMClassifier(**lgb_params0)
lgbmC.fit(X_train,y_train)

# %%
y_pred = lgbmC.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.867615129699463

# %% [markdown]
# <a id="8"></a>
# # <b>5 <span style='color:#94D4F6'>|</span> Evaluation</b>

# %%
# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[26327,  1338],
#        [ 3296,  4043]], dtype=int64)

# %%
def plot_confusion_matrix(confusion_matrix, classes):

    plt.imshow(confusion_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = confusion_matrix.max() / 2.
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            plt.text(j, i, format(confusion_matrix[i, j], fmt),
                     ha="center", va="center",
                     color="white" if confusion_matrix[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show the plot
    plt.show()

# %%
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
plot_confusion_matrix(cm, classes=['0','1'])
plt.show()

# %% [markdown]
# <a id="9"></a>
# # <b>6 <span style='color:#94D4F6'>|</span> Prediction</b>

# %%
lgbmC.fit(train_df, y_df)
# Out:
# LGBMClassifier(colsample_bytree=0.6533317052372195,
#                learning_rate=0.02280891846048891, max_depth=45,
#                min_child_samples=239, min_child_weight=2.829627687023079,
#                n_estimators=1378, num_leaves=44, subsample=0.9770315658429933,
#                subsample_freq=2)

# %%
predict = lgbmC.predict_proba(test)
max_probabilities = np.min(predict, axis=1)
print(max_probabilities)
# Out:
# [0.47907411 0.38344183 0.38344183 ... 0.45772421 0.40547264 0.13813267]

# %%
submission = pd.DataFrame({
    "id": testID,
    "Exited": max_probabilities
})

submission.to_csv("submission.csv", index=False)

# %% [markdown]
# <center>
# <span style="font-family:Comic Sans MS; color:red"><h2>Thank You😊</h2></span>
# </center>
