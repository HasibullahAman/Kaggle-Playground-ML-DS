# %% [markdown]
# <center><span style="font-family:Comic Sans MS; color:navy "><h1>Binary Classification with a Bank Churn Dataset</h1></span></center>

# %% [markdown]
# # <b>a <span style='color:#94D4F6'>|</span> Table of Conents</b>
# <a id="toc"></a>
# - [1. Import Libraries](#1)
# - [2. Read Dataset](#2)
# - [3. Visualization](#3)
# - [4. Preprocessing](#4)
# - [6. Split Dataset](#6)
# - [7. Modeling](#7)
# - [9. Evaluation](#8)
# - [8. Predict test data](#9)

# %% [markdown]
# # <b>b <span style='color:#94D4F6'>|</span> About DataSet</b>

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# The bank customer churn dataset is a commonly used dataset for predicting customer churn in the banking industry. It contains information on bank customers who either left the bank or continue to be a customer. The dataset includes the following attributes:
#
#
# **Customer ID:** A unique identifier for each customer
#
# **Surname:** The customer's surname or last name
#
# **Credit Score:** A numerical value representing the customer's credit score
#
# **Geography:** The country where the customer resides (France, Spain or Germany)
#
# **Gender:** The customer's gender (Male or Female)
#
# **Age:** The customer's age.
#
# **Tenure:** The number of years the customer has been with the bank
#
# **Balance:** The customer's account balance
#
# **NumOfProducts:** The number of bank products the customer uses (e.g., savings account, credit card)
#
# **HasCrCard:** Whether the customer has a credit card (1 = yes, 0 = no)
#
# **IsActiveMember:** Whether the customer is an active member (1 = yes, 0 = no)
#
# **EstimatedSalary:** The estimated salary of the customer
#
# **Exited:** Whether the customer has churned (1 = yes, 0 = no)

# %% [markdown]
# <a id="1"></a>
# # <b>1 <span style='color:#94D4F6'>|</span> Import Libraries</b>

# %%
import numpy as np # for calculation
import pandas as pd # for work with Dataset

# for Visualization 
import matplotlib.pyplot as plt
import seaborn as sns

# PreProcessing
from sklearn.model_selection import(
    train_test_split,# used to split the data into training and testing
    cross_val_score,
)

# Modeling
# Modeling
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %% [markdown]
# <a id="2"></a>
# # <b>2 <span style='color:#94D4F6'>|</span> Read Dataset</b>

# %%
# main dataset as df
# test datset as test
# sample_submission dataset as ss
# original dataset as od
df = pd.read_csv('Data/train.csv')
test = pd.read_csv('Data/test.csv')
ss = pd.read_csv('Data/sample_submission.csv')
od = pd.read_csv('Data/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
od.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          2    15647311      Hill          608     Spain  Female  41.0
# 2          3    15619304      Onio          502    France  Female  42.0
# 3          4    15701354      Boni          699    France  Female  39.0
# 4          5    15737888  Mitchell          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1        1.0             1.0
# 1       1   83807.86              1        0.0             1.0
# 2       8  159660.80              3        1.0             0.0
# 3       1       0.00              2        0.0             0.0
# 4       2  125510.82              1        NaN             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               165034 non-null  int64
#  1   CustomerId       165034 non-null  int64
#  2   Surname          165034 non-null  object
#  3   CreditScore      165034 non-null  int64
#  4   Geography        165034 non-null  object
#  5   Gender           165034 non-null  object
#  6   Age              165034 non-null  float64
#  7   Tenure           165034 non-null  int64
#  8   Balance          165034 non-null  float64
#  9   NumOfProducts    165034 non-null  int64
#  10  HasCrCard        165034 non-null  float64
#  11  IsActiveMember   165034 non-null  float64
#  12  EstimatedSalary  165034 non-null  float64
#  13  Exited           165034 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 17.6+ MB

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# Here, we have 14 columns with different data types, including both categorical and numerical variables. and as you can see, our dataset does not contain any null values. However, We need to perform preprocessing operations on these variables to transform them into suitable inputs for our modeling step.

# %% [markdown]
# ### Shape

# %%
print('shape of training dataset:')
print('there are {} rows and {} columns in training dataset.'.format(df.shape[0],df.shape[1]))
print('shape of test dataset:')
print('there are {} rows and {} columns in test dataset.'.format(test.shape[0],test.shape[1]))
print('shape of original dataset:')
print('there are {} rows and {} columns original dataset.'.format(od.shape[0],od.shape[1]))
# Out:
# shape of training dataset:
# there are 165034 rows and 14 columns in training dataset.
# shape of test dataset:
# there are 110023 rows and 13 columns in test dataset.
# shape of original dataset:
# there are 10002 rows and 14 columns original dataset.

# %% [markdown]
# ### Describe the dataset

# %%
df.describe().style.background_gradient(cmap = 'inferno')
# Out:
# <style type="text/css">
# #T_39397_row0_col0, #T_39397_row0_col2, #T_39397_row0_col3, #T_39397_row0_col4, #T_39397_row0_col6, #T_39397_row0_col7, #T_39397_row0_col8, #T_39397_row0_col10, #T_39397_row6_col1, #T_39397_row7_col0, #T_39397_row7_col1, #T_39397_row7_col5, #T_39397_row7_col9 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_39397_row0_col1, #T_39397_row7_col2 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_39397_row0_col5 {
#   background-color: #eb6628;
#   color: #f1f1f1;
# }
# #T_39397_row0_col9 {
#   background-color: #fcb216;
#   color: #000000;
# }
# #T_39397_row1_col0, #T_39397_row5_col0 {
#   background-color: #ba3655;
#   color: #f1f1f1;
# }
# #T_39397_row1_col1, #T_39397_row4_col1, #T_39397_row5_col1 {
#   background-color: #f9fc9d;
#   color: #000000;
# }
# #T_39397_row1_col2, #T_39397_row1_col3, #T_39397_row1_col4, #T_39397_row1_col6, #T_39397_row1_col7, #T_39397_row1_col8, #T_39397_row1_col10, #T_39397_row2_col1, #T_39397_row2_col2, #T_39397_row2_col3, #T_39397_row2_col4, #T_39397_row2_col6, #T_39397_row2_col7, #T_39397_row2_col8, #T_39397_row2_col10, #T_39397_row3_col0, #T_39397_row3_col2, #T_39397_row3_col3, #T_39397_row3_col4, #T_39397_row3_col5, #T_39397_row3_col6, #T_39397_row3_col7, #T_39397_row3_col8, #T_39397_row3_col9, #T_39397_row3_col10, #T_39397_row4_col2, #T_39397_row4_col3, #T_39397_row4_col4, #T_39397_row4_col5, #T_39397_row4_col6, #T_39397_row4_col7, #T_39397_row4_col8, #T_39397_row4_col10, #T_39397_row5_col2, #T_39397_row5_col3, #T_39397_row5_col4, #T_39397_row5_col5, #T_39397_row5_col6, #T_39397_row5_col7, #T_39397_row5_col8, #T_39397_row5_col10, #T_39397_row6_col2, #T_39397_row6_col3, #T_39397_row6_col4, #T_39397_row6_col6, #T_39397_row6_col7, #T_39397_row6_col8, #T_39397_row6_col10, #T_39397_row7_col3, #T_39397_row7_col4, #T_39397_row7_col6, #T_39397_row7_col7, #T_39397_row7_col8, #T_39397_row7_col10 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_39397_row1_col5 {
#   background-color: #4a0c6b;
#   color: #f1f1f1;
# }
# #T_39397_row1_col9 {
#   background-color: #d24644;
#   color: #f1f1f1;
# }
# #T_39397_row2_col0 {
#   background-color: #65156e;
#   color: #f1f1f1;
# }
# #T_39397_row2_col5, #T_39397_row2_col9 {
#   background-color: #57106e;
#   color: #f1f1f1;
# }
# #T_39397_row3_col1 {
#   background-color: #f6fa96;
#   color: #000000;
# }
# #T_39397_row4_col0 {
#   background-color: #550f6d;
#   color: #f1f1f1;
# }
# #T_39397_row4_col9 {
#   background-color: #88226a;
#   color: #f1f1f1;
# }
# #T_39397_row5_col9 {
#   background-color: #d94d3d;
#   color: #f1f1f1;
# }
# #T_39397_row6_col0 {
#   background-color: #f98c0a;
#   color: #f1f1f1;
# }
# #T_39397_row6_col5 {
#   background-color: #b3325a;
#   color: #f1f1f1;
# }
# #T_39397_row6_col9 {
#   background-color: #fb9906;
#   color: #000000;
# }
# </style>
# <table id="T_39397">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39397_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_39397_level0_col1" class="col_heading level0 col1" >CustomerId</th>
#       <th id="T_39397_level0_col2" class="col_heading level0 col2" >CreditScore</th>
#       <th id="T_39397_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_39397_level0_col4" class="col_heading level0 col4" >Tenure</th>
#       <th id="T_39397_level0_col5" class="col_heading level0 col5" >Balance</th>
#       <th id="T_39397_level0_col6" class="col_heading level0 col6" >NumOfProducts</th>
#       <th id="T_39397_level0_col7" class="col_heading level0 col7" >HasCrCard</th>
#       <th id="T_39397_level0_col8" class="col_heading level0 col8" >IsActiveMember</th>
#       <th id="T_39397_level0_col9" class="col_heading level0 col9" >EstimatedSalary</th>
#       <th id="T_39397_level0_col10" class="col_heading level0 col10" >Exited</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39397_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_39397_row0_col0" class="data row0 col0" >165034.000000</td>
#       <td id="T_39397_row0_col1" class="data row0 col1" >165034.000000</td>
#       <td id="T_39397_row0_col2" class="data row0 col2" >165034.000000</td>
#       <td id="T_39397_row0_col3" class="data row0 col3" >165034.000000</td>
#       <td id="T_39397_row0_col4" class="data row0 col4" >165034.000000</td>
#       <td id="T_39397_row0_col5" class="data row0 col5" >165034.000000</td>
#       <td id="T_39397_row0_col6" class="data row0 col6" >165034.000000</td>
#       <td id="T_39397_row0_col7" class="data row0 col7" >165034.000000</td>
#       <td id="T_39397_row0_col8" class="data row0 col8" >165034.000000</td>
#       <td id="T_39397_row0_col9" class="data row0 col9" >165034.000000</td>
#       <td id="T_39397_row0_col10" class="data row0 col10" >165034.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39397_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_39397_row1_col0" class="data row1 col0" >82516.500000</td>
#       <td id="T_39397_row1_col1" class="data row1 col1" >15692005.019026</td>
#       <td id="T_39397_row1_col2" class="data row1 col2" >656.454373</td>
#       <td id="T_39397_row1_col3" class="data row1 col3" >38.125888</td>
#       <td id="T_39397_row1_col4" class="data row1 col4" >5.020353</td>
#       <td id="T_39397_row1_col5" class="data row1 col5" >55478.086689</td>
#       <td id="T_39397_row1_col6" class="data row1 col6" >1.554455</td>
#       <td id="T_39397_row1_col7" class="data row1 col7" >0.753954</td>
#       <td id="T_39397_row1_col8" class="data row1 col8" >0.497770</td>
#       <td id="T_39397_row1_col9" class="data row1 col9" >112574.822734</td>
#       <td id="T_39397_row1_col10" class="data row1 col10" >0.211599</td>
#     </tr>
#     <tr>
#       <th id="T_39397_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_39397_row2_col0" class="data row2 col0" >47641.356500</td>
#       <td id="T_39397_row2_col1" class="data row2 col1" >71397.816791</td>
#       <td id="T_39397_row2_col2" class="data row2 col2" >80.103340</td>
#       <td id="T_39397_row2_col3" class="data row2 col3" >8.867205</td>
#       <td id="T_39397_row2_col4" class="data row2 col4" >2.806159</td>
#       <td id="T_39397_row2_col5" class="data row2 col5" >62817.663278</td>
#       <td id="T_39397_row2_col6" class="data row2 col6" >0.547154</td>
#       <td id="T_39397_row2_col7" class="data row2 col7" >0.430707</td>
#       <td id="T_39397_row2_col8" class="data row2 col8" >0.499997</td>
#       <td id="T_39397_row2_col9" class="data row2 col9" >50292.865585</td>
#       <td id="T_39397_row2_col10" class="data row2 col10" >0.408443</td>
#     </tr>
#     <tr>
#       <th id="T_39397_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_39397_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_39397_row3_col1" class="data row3 col1" >15565701.000000</td>
#       <td id="T_39397_row3_col2" class="data row3 col2" >350.000000</td>
#       <td id="T_39397_row3_col3" class="data row3 col3" >18.000000</td>
#       <td id="T_39397_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_39397_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_39397_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_39397_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_39397_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_39397_row3_col9" class="data row3 col9" >11.580000</td>
#       <td id="T_39397_row3_col10" class="data row3 col10" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_39397_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_39397_row4_col0" class="data row4 col0" >41258.250000</td>
#       <td id="T_39397_row4_col1" class="data row4 col1" >15633141.000000</td>
#       <td id="T_39397_row4_col2" class="data row4 col2" >597.000000</td>
#       <td id="T_39397_row4_col3" class="data row4 col3" >32.000000</td>
#       <td id="T_39397_row4_col4" class="data row4 col4" >3.000000</td>
#       <td id="T_39397_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_39397_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_39397_row4_col7" class="data row4

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# And here is some statistical information about our dataset. I will create clear plots to present the data more effectively.

# %% [markdown]
# ### Columns

# %%
df.columns
# Out:
# Index(['id', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# ### Drop ID&Surname columns

# %%
df.drop(['id', 'Surname'],axis=1,inplace=True)
od.drop(['RowNumber','Surname'],axis = 1, inplace = True)
test.drop(['id', 'Surname'],axis = 1,inplace =True)

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
# Here, I should identify if there is any similarity between the dataset ID and customer ID. In the previous statement, I mentioned that I dropped the dataset or row number, but I meant to say that I did not drop the customer ID. The customer ID is a unique identifier for each customer, and it is a valuable column for our analysis.

# %% [markdown]
# ### Determine the Categorical and Numerical Features

# %%
target = 'Exited'
obj_col = [x for x in df.select_dtypes(include=['object']).columns if x!=target]
num_col = [x for x in df.select_dtypes(exclude =['object']).columns if x!= target]
print(f'obj_columns: {obj_col}')
print(f'num_columns: {num_col}')
# Out:
# obj_columns: ['Geography', 'Gender']
# num_columns: ['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']

# %% [markdown]
# <a id="3"></a>
# # <b>3 <span style='color:#94D4F6'>|</span> Explanatory Data Analysis (EDA)</b>

# %% [markdown]
# <font size="3">Let's see what's the quality of raw dataset.</font>

# %%
def summary(df):
    sum = pd.DataFrame(df.dtypes,columns = ['dtypes'])
    sum['missing#'] = df.isna().sum()
    sum['missing%'] = (df.isna().sum())/len(df)
    sum['unique'] =  df.nunique().values
    sum['count'] = df.count().values
    return sum
summary(df).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_c3d40_row0_col1, #T_c3d40_row0_col2, #T_c3d40_row0_col4, #T_c3d40_row1_col1, #T_c3d40_row1_col2, #T_c3d40_row1_col4, #T_c3d40_row2_col1, #T_c3d40_row2_col2, #T_c3d40_row2_col3, #T_c3d40_row2_col4, #T_c3d40_row3_col1, #T_c3d40_row3_col2, #T_c3d40_row3_col3, #T_c3d40_row3_col4, #T_c3d40_row4_col1, #T_c3d40_row4_col2, #T_c3d40_row4_col3, #T_c3d40_row4_col4, #T_c3d40_row5_col1, #T_c3d40_row5_col2, #T_c3d40_row5_col3, #T_c3d40_row5_col4, #T_c3d40_row6_col1, #T_c3d40_row6_col2, #T_c3d40_row6_col4, #T_c3d40_row7_col1, #T_c3d40_row7_col2, #T_c3d40_row7_col3, #T_c3d40_row7_col4, #T_c3d40_row8_col1, #T_c3d40_row8_col2, #T_c3d40_row8_col3, #T_c3d40_row8_col4, #T_c3d40_row9_col1, #T_c3d40_row9_col2, #T_c3d40_row9_col3, #T_c3d40_row9_col4, #T_c3d40_row10_col1, #T_c3d40_row10_col2, #T_c3d40_row10_col4, #T_c3d40_row11_col1, #T_c3d40_row11_col2, #T_c3d40_row11_col3, #T_c3d40_row11_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c3d40_row0_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_c3d40_row1_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_c3d40_row6_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c3d40_row10_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3d40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3d40_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_c3d40_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_c3d40_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_c3d40_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_c3d40_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3d40_level0_row0" class="row_heading level0 row0" >CustomerId</th>
#       <td id="T_c3d40_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_c3d40_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c3d40_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_c3d40_row0_col3" class="data row0 col3" >23221</td>
#       <td id="T_c3d40_row0_col4" class="data row0 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row1" class="row_heading level0 row1" >CreditScore</th>
#       <td id="T_c3d40_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_c3d40_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c3d40_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c3d40_row1_col3" class="data row1 col3" >457</td>
#       <td id="T_c3d40_row1_col4" class="data row1 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row2" class="row_heading level0 row2" >Geography</th>
#       <td id="T_c3d40_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_c3d40_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_c3d40_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c3d40_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_c3d40_row2_col4" class="data row2 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row3" class="row_heading level0 row3" >Gender</th>
#       <td id="T_c3d40_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_c3d40_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_c3d40_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_c3d40_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_c3d40_row3_col4" class="data row3 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_c3d40_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_c3d40_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c3d40_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_c3d40_row4_col3" class="data row4 col3" >71</td>
#       <td id="T_c3d40_row4_col4" class="data row4 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row5" class="row_heading level0 row5" >Tenure</th>
#       <td id="T_c3d40_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_c3d40_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c3d40_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_c3d40_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_c3d40_row5_col4" class="data row5 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row6" class="row_heading level0 row6" >Balance</th>
#       <td id="T_c3d40_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_c3d40_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c3d40_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_c3d40_row6_col3" class="data row6 col3" >30075</td>
#       <td id="T_c3d40_row6_col4" class="data row6 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row7" class="row_heading level0 row7" >NumOfProducts</th>
#       <td id="T_c3d40_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_c3d40_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_c3d40_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_c3d40_row7_col3" class="data row7 col3" >4</td>
#       <td id="T_c3d40_row7_col4" class="data row7 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row8" class="row_heading level0 row8" >HasCrCard</th>
#       <td id="T_c3d40_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_c3d40_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_c3d40_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_c3d40_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_c3d40_row8_col4" class="data row8 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row9" class="row_heading level0 row9" >IsActiveMember</th>
#       <td id="T_c3d40_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_c3d40_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_c3d40_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_c3d40_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_c3d40_row9_col4" class="data row9 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row10" class="row_heading level0 row10" >EstimatedSalary</th>
#       <td id="T_c3d40_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_c3d40_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_c3d40_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_c3d40_row10_col3" class="data row10 col3" >55298</td>
#       <td id="T_c3d40_row10_col4" class="data row10 col4" >165034</td>
#     </tr>
#     <tr>
#       <th id="T_c3d40_level0_row11" class="row_heading level0 row11" >Exited</th>
#       <td id="T_c3d40_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_c3d40_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_c3d40_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_c3d40_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_c3d40_row11_col4" class="data row11 col4" >165034</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('----------test data ------------')
summary(test).style.background_gradient(cmap='Blues')
# Out:
# ----------test data ------------
# <style type="text/css">
# #T_cc8f8_row0_col1, #T_cc8f8_row0_col2, #T_cc8f8_row0_col4, #T_cc8f8_row1_col1, #T_cc8f8_row1_col2, #T_cc8f8_row1_col4, #T_cc8f8_row2_col1, #T_cc8f8_row2_col2, #T_cc8f8_row2_col3, #T_cc8f8_row2_col4, #T_cc8f8_row3_col1, #T_cc8f8_row3_col2, #T_cc8f8_row3_col3, #T_cc8f8_row3_col4, #T_cc8f8_row4_col1, #T_cc8f8_row4_col2, #T_cc8f8_row4_col3, #T_cc8f8_row4_col4, #T_cc8f8_row5_col1, #T_cc8f8_row5_col2, #T_cc8f8_row5_col3, #T_cc8f8_row5_col4, #T_cc8f8_row6_col1, #T_cc8f8_row6_col2, #T_cc8f8_row6_col4, #T_cc8f8_row7_col1, #T_cc8f8_row7_col2, #T_cc8f8_row7_col3, #T_cc8f8_row7_col4, #T_cc8f8_row8_col1, #T_cc8f8_row8_col2, #T_cc8f8_row8_col3, #T_cc8f8_row8_col4, #T_cc8f8_row9_col1, #T_cc8f8_row9_col2, #T_cc8f8_row9_col3, #T_cc8f8_row9_col4, #T_cc8f8_row10_col1, #T_cc8f8_row10_col2, #T_cc8f8_row10_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cc8f8_row0_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_cc8f8_row1_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_cc8f8_row6_col3 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_cc8f8_row10_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cc8f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc8f8_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_cc8f8_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_cc8f8_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_cc8f8_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_cc8f8_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc8f8_level0_row0" class="row_heading level0 row0" >CustomerId</th>
#       <td id="T_cc8f8_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_cc8f8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_cc8f8_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_cc8f8_row0_col3" class="data row0 col3" >19698</td>
#       <td id="T_cc8f8_row0_col4" class="data row0 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row1" class="row_heading level0 row1" >CreditScore</th>
#       <td id="T_cc8f8_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_cc8f8_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_cc8f8_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_cc8f8_row1_col3" class="data row1 col3" >454</td>
#       <td id="T_cc8f8_row1_col4" class="data row1 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row2" class="row_heading level0 row2" >Geography</th>
#       <td id="T_cc8f8_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_cc8f8_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_cc8f8_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_cc8f8_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_cc8f8_row2_col4" class="data row2 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row3" class="row_heading level0 row3" >Gender</th>
#       <td id="T_cc8f8_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_cc8f8_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_cc8f8_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_cc8f8_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_cc8f8_row3_col4" class="data row3 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_cc8f8_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_cc8f8_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_cc8f8_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_cc8f8_row4_col3" class="data row4 col3" >74</td>
#       <td id="T_cc8f8_row4_col4" class="data row4 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row5" class="row_heading level0 row5" >Tenure</th>
#       <td id="T_cc8f8_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_cc8f8_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_cc8f8_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_cc8f8_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_cc8f8_row5_col4" class="data row5 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row6" class="row_heading level0 row6" >Balance</th>
#       <td id="T_cc8f8_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_cc8f8_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_cc8f8_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_cc8f8_row6_col3" class="data row6 col3" >22513</td>
#       <td id="T_cc8f8_row6_col4" class="data row6 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row7" class="row_heading level0 row7" >NumOfProducts</th>
#       <td id="T_cc8f8_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_cc8f8_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_cc8f8_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_cc8f8_row7_col3" class="data row7 col3" >4</td>
#       <td id="T_cc8f8_row7_col4" class="data row7 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row8" class="row_heading level0 row8" >HasCrCard</th>
#       <td id="T_cc8f8_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_cc8f8_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_cc8f8_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_cc8f8_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_cc8f8_row8_col4" class="data row8 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row9" class="row_heading level0 row9" >IsActiveMember</th>
#       <td id="T_cc8f8_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_cc8f8_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_cc8f8_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_cc8f8_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_cc8f8_row9_col4" class="data row9 col4" >110023</td>
#     </tr>
#     <tr>
#       <th id="T_cc8f8_level0_row10" class="row_heading level0 row10" >EstimatedSalary</th>
#       <td id="T_cc8f8_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_cc8f8_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_cc8f8_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_cc8f8_row10_col3" class="data row10 col3" >41670</td>
#       <td id="T_cc8f8_row10_col4" class="data row10 col4" >110023</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Checking Correlation

# %%
columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
data = df[columns]
correlation_matrix = data.corr()
plt.figure(figsize=(10, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:17px; background-color: #EEEFFF; font-family:Comic Sans MS; color: #00011A; border: 1px #00011A">
#
# -  The values inside each cell represent the correlation coefficient, which ranges from -1 to 1. A correlation coefficient of 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation between the variables.
#
# - The diagonal line from the top-left to the bottom-right of the heatmap represents the correlation of each variable with itself, which is always 1. These values are not informative for analysis.
#
# - The upper and lower triangular portions of the heatmap are mirror images of each other since the correlation matrix is symmetric.

# %% [markdown]
# ### Label Distribution

# %%
counts = df['Exited'].value_counts()
df_counts = pd.DataFrame({'Class': counts.index, 'Count': counts.values})
print("Count of each Status:")
print(counts)
print("----------------------------------------------------------")
print()


sns.set_palette("Set2")
plt.figure(figsize=(6, 6))
plt.pie(df_counts['Count'], labels=df_counts['Class'], autopct='%1.1f%%',explode=(0.05,0.05), shadow=True, startangle=90, colors=sns.color_palette())
plt.title('Count Distribution of Target Variable')
plt.axis('equal')
plt.show()
# Out:
# Count of each Status:
# 0    130113
# 1     34921
# Name: Exited, dtype: int64
# ----------------------------------------------------------

# %%
columns_histogram_plot = ['CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary']
plt.figure(figsize=(15,10))
# loop through the number of rows and data frame columns
for i, columns in enumerate(columns_histogram_plot):
    plt.subplot(3,2,i+1)
    df[columns].hist(bins = 20,color = 'blue', edgecolor ='black')
    plt.title(f'distribution of {columns}')
    plt.xlabel(columns)
    plt.ylabel('Number of Cocustomer')
# Prevents overlap of plots
plt.tight_layout()
plt.show()

# %%
columns_pie_plot = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
for ax, column in zip(axes.flatten(), columns_pie_plot):
    category_counts = df[column].value_counts()
    ax.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f'Proportion of Customers by {column}')
# Prevents overlap of plots
plt.tight_layout()
plt.show()

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")
# Create box plots for the specified numerical columns stratified by 'Exited'
plt.figure(figsize=(12, 8))
for i, column in enumerate(['CreditScore', 'Age', 'Balance', 'EstimatedSalary'], 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='Exited', y=column, data=df)
    plt.title(f'{column} distribution by Exited')
    plt.xlabel('Exited')
    plt.ylabel(column)
# Prevents overlap of plots
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="4"></a>
# # <b>4 <span style='color:#94D4F6'>|</span> Preprocessing</b>

# %%
## utils/functions

# Unique Value
def uniqueValue(columns_name,df):
    return df[columns_name].unique()
# Null value
def DropNullValue(df):
    return df.dropna()

# Concatenate the datasets vertically
df = pd.concat(objs=[df, od]).reset_index(drop=True)

# drop null value
df = DropNullValue(df)
test = DropNullValue(test)

# %% [markdown]
# ### Encode Categorical Variables to Numerical

# %%
Geograpy_unique = uniqueValue('Geography',df)
Gender_unique = uniqueValue('Gender',df)
print(Geograpy_unique)
print(Gender_unique)
# Out:
# ['France' 'Spain' 'Germany']
# ['Male' 'Female']

# %%
cate_features = ['Geography', 'Gender']
# Geography
df['Geography'] = df['Geography'].map({
    'France' : 0,
    'Spain': 1,
    'Germany' : 2,
}).astype('int')

# Gender
df['Gender'] = df['Gender'].map({
    'Male' : 0,
    'Female' : 1,
}).astype('int')

# %% [markdown]
# ### Detect Outliers

# %%
tmp_df = df.copy()

# Calculate the mean and standard deviation for each column
means = tmp_df[num_col].mean()
std_devs = tmp_df[num_col].std()

# Define a threshold for what you consider to be an outlier, typically 3 standard deviations from the mean
n_stds = 6
thresholds = n_stds * std_devs

# Detect outliers
outliers = (np.abs(tmp_df[num_col] - means) > thresholds).any(axis=1)
print(f"Detected {sum(outliers)} that are more than {n_stds} SDs away from mean...")

# Remove Outlier
outliers_df = tmp_df[outliers]
print(f"Train data shape BEFORE outlier removal: {df.shape}")
df = tmp_df[~outliers].reset_index(drop=True)
print()
print(f"Train data shape AFTER outlier removal: {df.shape}")
# Out:
# Detected 13 that are more than 6 SDs away from mean...
# Train data shape BEFORE outlier removal: (175032, 12)
#
# Train data shape AFTER outlier removal: (175019, 12)

# %% [markdown]
# <a id="6"></a>
# ## Spliting The Dataset to Train and Test

# %%
df.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
y_df = df['Exited']
train_df = df.drop('Exited',axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df,y_df, test_size=0.2, shuffle=True, random_state=42)

# %% [markdown]
# <a id="7"></a>
# # <b>4 <span style='color:#94D4F6'>|</span> Modeling</b>

# %%
init_models = {
    # 'support vector kernel' : SVR(kernel= 'rbf'),
    # 'XGBOOST':XGBRegressor(),
    # 'Decision Tree' : DecisionTreeRegressor(),
    # 'Random Forest' : RandomForestRegressor(),
    # 'LGBM' : LGBMRegressor(),
    'xgb' : XGBClassifier(),
    'lgbmC' : LGBMClassifier()
}

# %%
R2 = []
models_names = []
for i,(key,model) in enumerate(init_models.items()):
    model.fit(X_train,y_train)
    models_names.append(key)
    R2.append(np.mean(cross_val_score(model,X_train,y_train,cv=5)))
models_scores = pd.DataFrame({'model name':models_names,'R2 score':R2})
models_scores.head(7)
# Out:
#   model name  R2 score
# 0        xgb  0.863636
# 1      lgbmC  0.864322

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.gaussian_process import GaussianProcessClassifier

init_models = {
    # 'Logistic Regression': LogisticRegression(),
    # 'Decision Tree': DecisionTreeClassifier(),
    # 'Random Forest': RandomForestClassifier(),
    # 'Gradient Boosting': GradientBoostingClassifier(),
    'Support Vector Machines': SVC(),
    # 'Neural Networks': MLPClassifier(),
    # 'Naive Bayes': GaussianNB(),
    # 'K-Nearest Neighbors': KNeighborsClassifier(),
    # 'AdaBoost': AdaBoostClassifier(),
    # 'Gaussian Processes': GaussianProcessClassifier(),
    # 'Extreme Gradient Boosting': XGBClassifier(),
    # 'CatBoost': CatBoostClassifier(),
    # 'LightGBM': LGBMClassifier(),
    # 'Random Forest Classifier': RandomForestClassifier(),
    # 'Extra Trees Classifier': ExtraTreesClassifier()
}

# %%
R2 = []
models_names = []
for i,(key,model) in enumerate(init_models.items()):
    model.fit(X_train,y_train)
    models_names.append(key)
    R2.append(np.mean(cross_val_score(model,X_train,y_train,cv=5)))
models_scores = pd.DataFrame({'model name':models_names,'R2 score':R2})
models_scores.head(7)
# Out:
#                 model name  R2 score
# 0  Support Vector Machines  0.788458
